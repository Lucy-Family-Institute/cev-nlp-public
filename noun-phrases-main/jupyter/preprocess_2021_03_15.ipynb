# %%
import glob
import pdftotext
from datetime import datetime
import spacy
import re
import nltk
import sys
from tqdm import tqdm 
from time import sleep 
import textacy

sys.path.append("/media/gabriel/Data/Projects/cev/noun-phrases/")
from src.util.common import Common

# %%
path = "/media/gabriel/Data/temp/scraping-master/sentencias_JyP/ext_data/output/sentencias/"

# %%
list_files = glob.glob(path+"*.pdf")
print(list_files[1:2])
# Out:
# ['/media/gabriel/Data/temp/scraping-master/sentencias_JyP/ext_data/output/sentencias/Aramis Machado Ortiz_29-jun-11.pdf']

# %%
import calendar
print(list(calendar.month_abbr))
# Out:
# ['', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

# %%
# Load 
count = 0 
list_texts_corpus = []
for i in tqdm(range(0, len(list_files)), desc ="Read Corpus"):  
    single_file = list_files[i]
    error_flag = False
    count += 1
    name = single_file.replace(path, '').split("_")
    date_time_str = name[1].replace('.pdf', '').replace('dic', 'dec').replace('agt','aug').replace('abr', 'apr').replace('ago', 'aug').replace('ene', 'jan').replace('2014', '14')
    try:
        date_time_obj = datetime.strptime(date_time_str, '%d-%b-%y')
    except:
        error_flag = True
        print(single_file)
        print("Error casting data.")
 
    file_name = name[0].replace(path, '')
    file_name = file_name.replace(date_time_str, '')
    file_name = file_name.replace('.pdf', '')
    
    with open(single_file, "rb") as f:
            pdf = pdftotext.PDF(f)
    if count % 4 == 0:
        break
    sigle_dict = {'path': single_file, 'file_name': file_name, 'date': date_time_obj, 'year': date_time_obj.year, 'month': date_time_obj.month, 'day': date_time_obj.day, 'num_pages': len(pdf), 'pages_raw': list(pdf),  
                  'text_raw': "\n\n".join(pdf), 'sentences': [], 'doc_parser': []}
#     print('\t -> ', count, date_time_str, 'file_name', sigle_dict['file_name'], 'date', sigle_dict['date'], 'num_pages', sigle_dict['num_pages'])
    list_texts_corpus.append(sigle_dict)
# Out:
# Read Corpus:   4%|▍         | 3/79 [00:04<01:47,  1.42s/it]

# %%
count = 0
for item in list_texts_corpus:
    count += 1
    print('-> ', count, '\tfile_name:', item['file_name'][:50].zfill(50).replace('0', ' '), '\tdate:', item['date'], '\tnum_pages:', item['num_pages'])
# Out:
# ->  1 	file_name:                              Alexi Mancilla García 	date: 2016-06-15 00:00:00 	num_pages: 449
# ->  2 	file_name:                               Aramis Machado Ortiz 	date: 2011-06-29 00:00:00 	num_pages: 38
# ->  3 	file_name:       Armando Madriaga Picón y Jesús Noraldo Basto 	date: 2013-12-06 00:00:00 	num_pages: 291
# ->  4 	file_name:                     Arnubio Triana Mahecha y otros 	date: 2014-12-16 00:00:00 	num_pages: 970
# ->  5 	file_name:                        Atanael Matajudios Buitrago 	date: 2016-12-07 00:00:00 	num_pages: 1282
# ->  6 	file_name:               Darío Enrique Vélez Trujillo y otros 	date: 2014-08-27 00:00:00 	num_pages: 1180
# ->  7 	file_name:                               Edgar Ignacio Fierro 	date: 2018-12-18 00:00:00 	num_pages: 1758
# ->  8 	file_name:       Edilberto de Jesús Cañas Chavarriaga y otros 	date: 2015-09-24 00:00:00 	num_pages: 786
# ->  9 	file_name:                            Edison Giraldo Paniagua 	date: 2012-07-30 00:00:00 	num_pages: 156

# %%
name_global_model_spacy = "es_core_news_sm"
nlp = spacy.load(name_global_model_spacy)
pattern = r'(<VERB>?<ADV>*<VERB>+)'
verb_pattern = [{"POS": "VERB", "OP": "*"},{"POS": "ADV", "OP": "*"},{"POS": "VERB", "OP": "+"},{"POS": "PART", "OP": "*"}]

# %%
text_page = list_texts_corpus[0]['pages_raw'][1]
print(text_page)
count = 0
doc = nlp(text_page)
# print(doc.text)
# for token in doc:
#     print(token.text, token.pos_, token.dep_)
for np in doc.noun_chunks:
    count += 1 
    print('\t', count, 'chunk', np.text)
    if count == 20:
        break
# Out:
#                                                        Alexi Mancilla García
#                                                            Rad. 2006 80848
#                               POSTULADO
#       Alexi Mancilla García, conocido con el alias de “Zambrano” nació
# el 1 de febrero de 1966 en la ciudad de Cartagena de Indias. Hijo de
# Manuel Mancilla Bolívar (fallecido) y Eva García Julio Peña, con diez
# hermanos. Estuvo casado con Cecilia Calderón Manrique de la cual se
# divorció y es padre de dos hijos.
#       Por orden de trabajo No. 12045 de 2011 se realizó el informe de
# plena identidad en el que se concluyó que una vez hecho el cotejo de
# las huellas que aparecen en la copia de la tarjeta decadactilar con la
# impresa en la tarjeta expedida por la Registraduría Nacional del Estado
# Civil, corresponde -en ambos casos- a Alexi Mancilla García con
# cédula de ciudadanía No. 98.530.085 de María la Baja (Bolívar).
#       Residió en el municipio de María la Baja y estudió hasta cuarto
# de bachillerato en el colegio Rafael Uribe Uribe. En el año 1984 ingresó
# al Ejército Nacional como soldado del Batallón de Infantería No. 6 de
# Cartagena ubicado en Riohacha (Guajira). Posteriormente, se unió a la
# Escuela de Suboficiales Inocencio Chinga de Tolemaida, institución
# que en 1991 lo ascendió al rango de Cabo Segundo, y fue trasladado a
# Cartago (Valle), para desempeñarse como escolta del Mayor General
# Zúñiga Chaparro en la Tercera División de Infantería de Cali.
#       Luego, fue reubicado en el Batallón de Ingenieros Agustín Codazzi
# de Palmira (Valle), de allí lo transfirieron al de Infantería No. 27 con
# sede en Florencia (Caquetá), posteriormente ingresó a la Escuela de
# Infantería de Bogotá, donde fue ascendido al rango de Sargento
# Segundo del Ejército. Así mismo, fue enviado al Batallón de Infantería
# Magdalena con sede en Pitalito (Huila), para pasar después a la Sección
# de Inteligencia del Ejército de Neiva, y terminar en al Batallón Cumarí
# de Leticia (Amazonas), sitio en el que permaneció hasta el año 2000,
# porque mediante resolución administrativa se había ordenado su retiro
#                                      2
#
# 	 1 chunk Alexi Mancilla García
#                                                            Rad
# 	 2 chunk 2006 80848
#                               POSTULADO
#       Alexi Mancilla García
# 	 3 chunk el alias
# 	 4 chunk “Zambrano”
# 	 5 chunk la ciudad
# 	 6 chunk Cartagena de Indias
# 	 7 chunk Hijo de
# Manuel Mancilla Bolívar
# 	 8 chunk Eva García Julio Peña
# 	 9 chunk hermanos
# 	 10 chunk Cecilia Calderón Manrique
# 	 11 chunk la cual
# 	 12 chunk se
# 	 13 chunk padre
# 	 14 chunk hijos
# 	 15 chunk orden
# 	 16 chunk trabajo
# 	 17 chunk 12045
# 	 18 chunk se
# 	 19 chunk el informe
# 	 20 chunk identidad

# %%
text_page = re.sub('\s+',' ', list_texts_corpus[0]['pages_raw'][1])
print(text_page)
count = 0
doc = nlp(text_page)
# print(doc.text)
# for token in doc:
#     print(token.text, token.pos_, token.dep_)
for np in doc.noun_chunks:
    count += 1 
    print('\t', count, 'chunk', np.text)
    if count == 20:
        break
# Out:
#  Alexi Mancilla García Rad. 2006 80848 POSTULADO Alexi Mancilla García, conocido con el alias de “Zambrano” nació el 1 de febrero de 1966 en la ciudad de Cartagena de Indias. Hijo de Manuel Mancilla Bolívar (fallecido) y Eva García Julio Peña, con diez hermanos. Estuvo casado con Cecilia Calderón Manrique de la cual se divorció y es padre de dos hijos. Por orden de trabajo No. 12045 de 2011 se realizó el informe de plena identidad en el que se concluyó que una vez hecho el cotejo de las huellas que aparecen en la copia de la tarjeta decadactilar con la impresa en la tarjeta expedida por la Registraduría Nacional del Estado Civil, corresponde -en ambos casos- a Alexi Mancilla García con cédula de ciudadanía No. 98.530.085 de María la Baja (Bolívar). Residió en el municipio de María la Baja y estudió hasta cuarto de bachillerato en el colegio Rafael Uribe Uribe. En el año 1984 ingresó al Ejército Nacional como soldado del Batallón de Infantería No. 6 de Cartagena ubicado en Riohacha (Guajira). Posteriormente, se unió a la Escuela de Suboficiales Inocencio Chinga de Tolemaida, institución que en 1991 lo ascendió al rango de Cabo Segundo, y fue trasladado a Cartago (Valle), para desempeñarse como escolta del Mayor General Zúñiga Chaparro en la Tercera División de Infantería de Cali. Luego, fue reubicado en el Batallón de Ingenieros Agustín Codazzi de Palmira (Valle), de allí lo transfirieron al de Infantería No. 27 con sede en Florencia (Caquetá), posteriormente ingresó a la Escuela de Infantería de Bogotá, donde fue ascendido al rango de Sargento Segundo del Ejército. Así mismo, fue enviado al Batallón de Infantería Magdalena con sede en Pitalito (Huila), para pasar después a la Sección de Inteligencia del Ejército de Neiva, y terminar en al Batallón Cumarí de Leticia (Amazonas), sitio en el que permaneció hasta el año 2000, porque mediante resolución administrativa se había ordenado su retiro 2
# 	 1 chunk Alexi Mancilla García Rad
# 	 2 chunk 2006
# 	 3 chunk POSTULADO
# 	 4 chunk Alexi Mancilla García
# 	 5 chunk el alias
# 	 6 chunk “Zambrano”
# 	 7 chunk la ciudad
# 	 8 chunk Cartagena de Indias
# 	 9 chunk Hijo
# 	 10 chunk Manuel Mancilla Bolívar
# 	 11 chunk Eva García Julio Peña
# 	 12 chunk hermanos
# 	 13 chunk Cecilia Calderón Manrique
# 	 14 chunk la cual
# 	 15 chunk se
# 	 16 chunk padre
# 	 17 chunk hijos
# 	 18 chunk orden
# 	 19 chunk trabajo
# 	 20 chunk 12045

# %%
print('part 1')
text_page1 = list_texts_corpus[0]['text_raw']
# print(text_page1)
sents = nltk.sent_tokenize(text_page1)
print('# sents:',len(sents), "sample: ", sents[1:4])
print('='*150)
print('part 2')
text_page2 = list_texts_corpus[0]['text_raw']
text_page2 = re.sub('\n+',' ', text_page2)
text_page2 = re.sub('\s+',' ', text_page2)
# print(text_page2)
sents2 = nltk.sent_tokenize(text_page2)
print('# sents:',len(sents), "sample: ", sents2[1:4])
# Out:
# part 1
# # sents: 5777 sample:  ['007 de 2016.', 'Bogotá, D.C., 15 de junio de dos mil dieciséis (2016).', 'DECISIÓN\n      Agotada la audiencia de control formal y material de los cargos,\nsolicitada por el Fiscal 11 de la Unidad de Justicia Transicional y\nfinalizado el incidente de reparación integral, procede la sala a proferir\nsentencia parcial, bajo los lineamientos del artículo 24 de la Ley 975\nde 2005, contra el postulado por el Gobierno Nacional ALEXI\nMANCILLA GARCÍA, a.']
# ======================================================================================================================================================
# part 2
# # sents: 5777 sample:  ['007 de 2016.', 'Bogotá, D.C., 15 de junio de dos mil dieciséis (2016).', 'DECISIÓN Agotada la audiencia de control formal y material de los cargos, solicitada por el Fiscal 11 de la Unidad de Justicia Transicional y finalizado el incidente de reparación integral, procede la sala a proferir sentencia parcial, bajo los lineamientos del artículo 24 de la Ley 975 de 2005, contra el postulado por el Gobierno Nacional ALEXI MANCILLA GARCÍA, a.']

# %%
count_sent = 0
for item in sents2[13:25]:
    count_sent += 1
    print('sent # ', count_sent, '-'*150)
    print('\t without process:', item)
    doc = nlp(item)
    for np in doc.noun_chunks:
        count += 1 
        print('\t\t wp false:', count, 'chunk:', np.text)
    #item = re.sub('[\W_]+', ' ', item, flags=re.UNICODE) # [^A-Za-z0-9_] [\W_] [^-/().&' \w]|_
    item = re.sub(r"[^- \w]|_", "", item)    
    print('\t with process:', item)
    doc = nlp(item)
    np_state = True
    for np in doc.noun_chunks:
        np_state = False
        count += 1 
        print('\t\t wp true:', count, 'chunk:', np.text)
    if np_state:
        print('\t\t error: This sentence has no noun phrase.')
    noun_pharses=set()
    noun_pharses_nc=[]    
    for nc in doc.noun_chunks:
        noun_dict = {'nc': nc, 'np': []}
        for np in [nc, doc[nc.root.left_edge.i:nc.root.right_edge.i+1]]:
            noun_dict['np'].append(np)
        # noun_pharses.add(np)
        noun_pharses_nc.append(noun_dict)
    print('\t\t wp nc true:', noun_pharses_nc)
    for entity in doc.ents:
        print('\t\t ent nc true:', entity.text, entity.label_)
    verb_pattern = [{"POS": "VERB", "OP": "*"},{"POS": "ADV", "OP": "*"},{"POS": "VERB", "OP": "+"},{"POS": "PART", "OP": "*"}]
    nlp_verb_phrases = textacy.make_spacy_doc(item, lang=name_global_model_spacy)
#     verb_phrases = textacy.extract.pos_regex_matches(nlp_verb_phrases, pattern)
#     # Print all Verb Phrase
#     for chunk in verb_phrases:
#         print('\t\t wp nc true verb_phrases:', chunk.text)
    verb_phrases_2 = textacy.extract.matches(nlp_verb_phrases, verb_pattern)
    for chunk in verb_phrases_2:
        print('\t\t wp nc true verb_phrases 2:', chunk.text)
# Out:
# sent #  1 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: En el año 1984 ingresó al Ejército Nacional como soldado del Batallón de Infantería No.
# 		 wp false: 51 chunk: Ejército Nacional
# 		 wp false: 52 chunk: soldado
# 		 wp false: 53 chunk: Batallón de Infantería No
# 	 with process: En el año 1984 ingresó al Ejército Nacional como soldado del Batallón de Infantería No
# 		 wp true: 54 chunk: Ejército Nacional
# 		 wp true: 55 chunk: soldado
# 		 wp true: 56 chunk: Batallón de Infantería No
# 		 wp nc true: [{'nc': Ejército Nacional, 'np': [Ejército Nacional, al Ejército Nacional]}, {'nc': soldado, 'np': [soldado, como soldado del Batallón de Infantería No]}, {'nc': Batallón de Infantería No, 'np': [Batallón de Infantería No, del Batallón de Infantería No]}]
# 		 ent nc true: Ejército Nacional MISC
# 		 ent nc true: Batallón de Infantería No MISC
# 		 wp nc true verb_phrases 2: ingresó
# sent #  2 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: 6 de Cartagena ubicado en Riohacha (Guajira).
# 		 wp false: 57 chunk: Cartagena
# 		 wp false: 58 chunk: Riohacha
# 		 wp false: 59 chunk: Guajira
# 	 with process: 6 de Cartagena ubicado en Riohacha Guajira
# 		 wp true: 60 chunk: Cartagena
# 		 wp true: 61 chunk: Riohacha Guajira
# 		 wp nc true: [{'nc': Cartagena, 'np': [Cartagena, de Cartagena]}, {'nc': Riohacha Guajira, 'np': [Riohacha Guajira, en Riohacha Guajira]}]
# 		 ent nc true: Cartagena LOC
# 		 ent nc true: Riohacha Guajira LOC
# sent #  3 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: Posteriormente, se unió a la Escuela de Suboficiales Inocencio Chinga de Tolemaida, institución que en 1991 lo ascendió al rango de Cabo Segundo, y fue trasladado a Cartago (Valle), para desempeñarse como escolta del Mayor General Zúñiga Chaparro en la Tercera División de Infantería de Cali.
# 		 wp false: 62 chunk: se
# 		 wp false: 63 chunk: la Escuela de Suboficiales Inocencio Chinga de Tolemaida
# 		 wp false: 64 chunk: institución
# 		 wp false: 65 chunk: 1991
# 		 wp false: 66 chunk: lo
# 		 wp false: 67 chunk: rango
# 		 wp false: 68 chunk: Cabo Segundo
# 		 wp false: 69 chunk: Cartago
# 		 wp false: 70 chunk: Valle
# 		 wp false: 71 chunk: escolta
# 		 wp false: 72 chunk: Mayor General Zúñiga Chaparro
# 		 wp false: 73 chunk: la Tercera División de Infantería de Cali
# 	 with process: Posteriormente se unió a la Escuela de Suboficiales Inocencio Chinga de Tolemaida institución que en 1991 lo ascendió al rango de Cabo Segundo y fue trasladado a Cartago Valle para desempeñarse como escolta del Mayor General Zúñiga Chaparro en la Tercera División de Infantería de Cali
# 		 wp true: 74 chunk: se
# 		 wp true: 75 chunk: la Escuela de Suboficiales Inocencio Chinga de Tolemaida
# 		 wp true: 76 chunk: institución
# 		 wp true: 77 chunk: 1991
# 		 wp true: 78 chunk: lo
# 		 wp true: 79 chunk: rango
# 		 wp true: 80 chunk: Cabo Segundo
# 		 wp true: 81 chunk: Cartago Valle
# 		 wp true: 82 chunk: escolta
# 		 wp true: 83 chunk: Mayor General Zúñiga Chaparro
# 		 wp true: 84 chunk: la Tercera División de Infantería de Cali
# 		 wp nc true: [{'nc': se, 'np': [se, se]}, {'nc': la Escuela de Suboficiales Inocencio Chinga de Tolemaida, 'np': [la Escuela de Suboficiales Inocencio Chinga de Tolemaida, a la Escuela de Suboficiales Inocencio Chinga de Tolemaida institución]}, {'nc': institución, 'np': [institución, institución]}, {'nc': 1991, 'np': [1991, en 1991]}, {'nc': lo, 'np': [lo, lo]}, {'nc': rango, 'np': [rango, al rango de Cabo Segundo]}, {'nc': Cabo Segundo, 'np': [Cabo Segundo, de Cabo Segundo]}, {'nc': Cartago Valle, 'np': [Cartago Valle, a Cartago Valle]}, {'nc': escolta, 'np': [escolta, como escolta del Mayor General Zúñiga Chaparro]}, {'nc': Mayor General Zúñiga Chaparro, 'np': [Mayor General Zúñiga Chaparro, del Mayor General Zúñiga Chaparro]}, {'nc': la Tercera División de Infantería de Cali, 'np': [la Tercera División de Infantería de Cali, en la Tercera División de Infantería de Cali]}]
# 		 ent nc true: Escuela de Suboficiales Inocencio Chinga de Tolemaida ORG
# 		 ent nc true: Cabo Segundo LOC
# 		 ent nc true: Cartago Valle LOC
# 		 ent nc true: Mayor General Zúñiga Chaparro LOC
# 		 ent nc true: Tercera División de Infantería de Cali MISC
# 		 wp nc true verb_phrases 2: unió
# 		 wp nc true verb_phrases 2: ascendió
# 		 wp nc true verb_phrases 2: trasladado
# 		 wp nc true verb_phrases 2: desempeñarse
# sent #  4 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: Luego, fue reubicado en el Batallón de Ingenieros Agustín Codazzi de Palmira (Valle), de allí lo transfirieron al de Infantería No.
# 		 wp false: 85 chunk: el Batallón de Ingenieros Agustín Codazzi de Palmira
# 		 wp false: 86 chunk: Valle
# 		 wp false: 87 chunk: lo
# 		 wp false: 88 chunk: Infantería No
# 	 with process: Luego fue reubicado en el Batallón de Ingenieros Agustín Codazzi de Palmira Valle de allí lo transfirieron al de Infantería No
# 		 wp true: 89 chunk: el Batallón de Ingenieros Agustín Codazzi de Palmira Valle
# 		 wp true: 90 chunk: lo
# 		 wp true: 91 chunk: Infantería No
# 		 wp nc true: [{'nc': el Batallón de Ingenieros Agustín Codazzi de Palmira Valle, 'np': [el Batallón de Ingenieros Agustín Codazzi de Palmira Valle, en el Batallón de Ingenieros Agustín Codazzi de Palmira Valle]}, {'nc': lo, 'np': [lo, lo]}, {'nc': Infantería No, 'np': [Infantería No, al de Infantería No]}]
# 		 ent nc true: Batallón de Ingenieros Agustín Codazzi MISC
# 		 ent nc true: Palmira Valle PER
# 		 ent nc true: Infantería No ORG
# 		 wp nc true verb_phrases 2: reubicado
# 		 wp nc true verb_phrases 2: transfirieron
# sent #  5 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: 27 con sede en Florencia (Caquetá), posteriormente ingresó a la Escuela de Infantería de Bogotá, donde fue ascendido al rango de Sargento Segundo del Ejército.
# 		 wp false: 92 chunk: sede
# 		 wp false: 93 chunk: Florencia
# 		 wp false: 94 chunk: Caquetá
# 		 wp false: 95 chunk: la Escuela de Infantería de Bogotá
# 		 wp false: 96 chunk: donde
# 		 wp false: 97 chunk: rango
# 		 wp false: 98 chunk: Sargento Segundo del Ejército
# 	 with process: 27 con sede en Florencia Caquetá posteriormente ingresó a la Escuela de Infantería de Bogotá donde fue ascendido al rango de Sargento Segundo del Ejército
# 		 wp true: 99 chunk: sede
# 		 wp true: 100 chunk: Florencia Caquetá
# 		 wp true: 101 chunk: la Escuela de Infantería de Bogotá
# 		 wp true: 102 chunk: donde
# 		 wp true: 103 chunk: rango
# 		 wp true: 104 chunk: Sargento Segundo del Ejército
# 		 wp nc true: [{'nc': sede, 'np': [sede, con sede]}, {'nc': Florencia Caquetá, 'np': [Florencia Caquetá, en Florencia Caquetá]}, {'nc': la Escuela de Infantería de Bogotá, 'np': [la Escuela de Infantería de Bogotá, a la Escuela de Infantería de Bogotá donde fue ascendido al rango de Sargento Segundo del Ejército]}, {'nc': donde, 'np': [donde, donde]}, {'nc': rango, 'np': [rango, al rango de Sargento Segundo del Ejército]}, {'nc': Sargento Segundo del Ejército, 'np': [Sargento Segundo del Ejército, de Sargento Segundo del Ejército]}]
# 		 ent nc true: Florencia Caquetá LOC
# 		 ent nc true: Escuela de Infantería de Bogotá ORG
# 		 ent nc true: Sargento Segundo del Ejército PER
# 		 wp nc true verb_phrases 2: posteriormente ingresó
# 		 wp nc true verb_phrases 2: ingresó
# 		 wp nc true verb_phrases 2: ascendido
# sent #  6 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: Así mismo, fue enviado al Batallón de Infantería Magdalena con sede en Pitalito (Huila), para pasar después a la Sección de Inteligencia del Ejército de Neiva, y terminar en al Batallón Cumarí de Leticia (Amazonas), sitio en el que permaneció hasta el año 2000, porque mediante resolución administrativa se había ordenado su retiro 2 Alexi Mancilla García Rad.
# 		 wp false: 105 chunk: Batallón de Infantería Magdalena
# 		 wp false: 106 chunk: sede
# 		 wp false: 107 chunk: Pitalito
# 		 wp false: 108 chunk: Huila
# 		 wp false: 109 chunk: la Sección de Inteligencia del Ejército de Neiva
# 		 wp false: 110 chunk: Batallón Cumarí de Leticia
# 		 wp false: 111 chunk: Amazonas
# 		 wp false: 112 chunk: sitio
# 		 wp false: 113 chunk: resolución
# 		 wp false: 114 chunk: se
# 		 wp false: 115 chunk: su retiro
# 		 wp false: 116 chunk: Alexi Mancilla García Rad
# 	 with process: Así mismo fue enviado al Batallón de Infantería Magdalena con sede en Pitalito Huila para pasar después a la Sección de Inteligencia del Ejército de Neiva y terminar en al Batallón Cumarí de Leticia Amazonas sitio en el que permaneció hasta el año 2000 porque mediante resolución administrativa se había ordenado su retiro 2 Alexi Mancilla García Rad
# 		 wp true: 117 chunk: Batallón de Infantería Magdalena
# 		 wp true: 118 chunk: sede
# 		 wp true: 119 chunk: Pitalito Huila
# 		 wp true: 120 chunk: la Sección de Inteligencia del Ejército de Neiva
# 		 wp true: 121 chunk: Batallón Cumarí de Leticia Amazonas
# 		 wp true: 122 chunk: resolución
# 		 wp true: 123 chunk: se
# 		 wp true: 124 chunk: su retiro
# 		 wp true: 125 chunk: Alexi Mancilla García Rad
# 		 wp nc true: [{'nc': Batallón de Infantería Magdalena, 'np': [Batallón de Infantería Magdalena, al Batallón de Infantería Magdalena]}, {'nc': sede, 'np': [sede, con sede en Pitalito Huila]}, {'nc': Pitalito Huila, 'np': [Pitalito Huila, en Pitalito Huila]}, {'nc': la Sección de Inteligencia del Ejército de Neiva, 'np': [la Sección de Inteligencia del Ejército de Neiva, a la Sección de Inteligencia del Ejército de Neiva]}, {'nc': Batallón Cumarí de Leticia Amazonas, 'np': [Batallón Cumarí de Leticia Amazonas, en al Batallón Cumarí de Leticia Amazonas]}, {'nc': resolución, 'np': [resolución, mediante resolución administrativa]}, {'nc': se, 'np': [se, se]}, {'nc': su retiro, 'np': [su retiro, su retiro 2 Alexi Mancilla García Rad]}, {'nc': Alexi Mancilla García Rad, 'np': [Alexi Mancilla García Rad, Alexi Mancilla García Rad]}]
# 		 ent nc true: Batallón MISC
# 		 ent nc true: Infantería Magdalena PER
# 		 ent nc true: Pitalito Huila LOC
# 		 ent nc true: Sección de Inteligencia del Ejército de Neiva ORG
# 		 ent nc true: Batallón Cumarí de Leticia Amazonas MISC
# 		 ent nc true: Alexi Mancilla García Rad PER
# 		 wp nc true verb_phrases 2: enviado
# 		 wp nc true verb_phrases 2: pasar
# 		 wp nc true verb_phrases 2: terminar
# 		 wp nc true verb_phrases 2: sitio
# 		 wp nc true verb_phrases 2: permaneció
# 		 wp nc true verb_phrases 2: había
# 		 wp nc true verb_phrases 2: había ordenado
# 		 wp nc true verb_phrases 2: ordenado
# sent #  7 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: 2006 80848 de la institución; incluso, le estaban adelantado dos investigaciones disciplinarias, según el relato del mismo postulado.
# 		 wp false: 126 chunk: 2006 80848
# 		 wp false: 127 chunk: la institución
# 		 wp false: 128 chunk: le
# 		 wp false: 129 chunk: investigaciones
# 		 wp false: 130 chunk: el relato
# 		 wp false: 131 chunk: mismo postulado
# 	 with process: 2006 80848 de la institución incluso le estaban adelantado dos investigaciones disciplinarias según el relato del mismo postulado
# 		 wp true: 132 chunk: 2006 80848
# 		 wp true: 133 chunk: la institución
# 		 wp true: 134 chunk: le
# 		 wp true: 135 chunk: investigaciones
# 		 wp true: 136 chunk: el relato
# 		 wp true: 137 chunk: mismo postulado
# 		 wp nc true: [{'nc': 2006 80848, 'np': [2006 80848, 2006 80848 de la institución]}, {'nc': la institución, 'np': [la institución, de la institución]}, {'nc': le, 'np': [le, le]}, {'nc': investigaciones, 'np': [investigaciones, dos investigaciones disciplinarias]}, {'nc': el relato, 'np': [el relato, según el relato del mismo postulado]}, {'nc': mismo postulado, 'np': [mismo postulado, del mismo postulado]}]
# 		 wp nc true verb_phrases 2: estaban
# 		 wp nc true verb_phrases 2: estaban adelantado
# 		 wp nc true verb_phrases 2: adelantado
# sent #  8 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: En audiencia pública celebrada el 13 de agosto de 2012 señaló el acriminado que, como consecuencia de su retiro del Ejército Nacional su proyecto de vida cambió, razón por la que se vio obligado a regresar al municipio de María La Baja, aprovechando su estadía para cuidar a su progenitora hasta el día de su fallecimiento.
# 		 wp false: 138 chunk: audiencia
# 		 wp false: 139 chunk: el acriminado
# 		 wp false: 140 chunk: consecuencia
# 		 wp false: 141 chunk: su retiro
# 		 wp false: 142 chunk: Ejército Nacional
# 		 wp false: 143 chunk: su proyecto
# 		 wp false: 144 chunk: vida
# 		 wp false: 145 chunk: razón
# 		 wp false: 146 chunk: se
# 		 wp false: 147 chunk: municipio
# 		 wp false: 148 chunk: María La Baja
# 		 wp false: 149 chunk: su estadía
# 		 wp false: 150 chunk: su progenitora
# 		 wp false: 151 chunk: el día
# 		 wp false: 152 chunk: su fallecimiento
# 	 with process: En audiencia pública celebrada el 13 de agosto de 2012 señaló el acriminado que como consecuencia de su retiro del Ejército Nacional su proyecto de vida cambió razón por la que se vio obligado a regresar al municipio de María La Baja aprovechando su estadía para cuidar a su progenitora hasta el día de su fallecimiento
# 		 wp true: 153 chunk: audiencia
# 		 wp true: 154 chunk: el acriminado
# 		 wp true: 155 chunk: consecuencia
# 		 wp true: 156 chunk: su retiro
# 		 wp true: 157 chunk: Ejército Nacional
# 		 wp true: 158 chunk: su proyecto
# 		 wp true: 159 chunk: vida
# 		 wp true: 160 chunk: razón
# 		 wp true: 161 chunk: se
# 		 wp true: 162 chunk: municipio
# 		 wp true: 163 chunk: María La Baja
# 		 wp true: 164 chunk: su estadía
# 		 wp true: 165 chunk: su progenitora
# 		 wp true: 166 chunk: el día
# 		 wp true: 167 chunk: su fallecimiento
# 		 wp nc true: [{'nc': audiencia, 'np': [audiencia, En audiencia pública celebrada el 13 de agosto de 2012]}, {'nc': el acriminado, 'np': [el acriminado, el acriminado que como consecuencia de su retiro del Ejército Nacional su proyecto de vida cambió razón por la que se vio obligado a regresar al municipio de María La Baja aprovechando su estadía para cuidar a su progenitora hasta el día de su fallecimiento]}, {'nc': consecuencia, 'np': [consecuencia, consecuencia]}, {'nc': su retiro, 'np': [su retiro, como consecuencia de su retiro del Ejército Nacional]}, {'nc': Ejército Nacional, 'np': [Ejército Nacional, del Ejército Nacional]}, {'nc': su proyecto, 'np': [su proyecto, su proyecto de vida]}, {'nc': vida, 'np': [vida, de vida]}, {'nc': razón, 'np': [razón, razón por la que se vio obligado a regresar al municipio de María La Baja aprovechando su estadía para cuidar a su progenitora hasta el día de su fallecimiento]}, {'nc': se, 'np': [se, se]}, {'nc': municipio, 'np': [municipio, al municipio de María La Baja]}, {'nc': María La Baja, 'np': [María La Baja, de María La Baja]}, {'nc': su estadía, 'np': [su estadía, su estadía]}, {'nc': su progenitora, 'np': [su progenitora, a su progenitora]}, {'nc': el día, 'np': [el día, hasta el día de su fallecimiento]}, {'nc': su fallecimiento, 'np': [su fallecimiento, de su fallecimiento]}]
# 		 ent nc true: Ejército Nacional MISC
# 		 ent nc true: María La Baja LOC
# 		 wp nc true verb_phrases 2: señaló
# 		 wp nc true verb_phrases 2: cambió
# 		 wp nc true verb_phrases 2: vio
# 		 wp nc true verb_phrases 2: regresar
# 		 wp nc true verb_phrases 2: aprovechando
# 		 wp nc true verb_phrases 2: cuidar
# sent #  9 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: En su natal tierra tuvo la «oportunidad» de conocer a Rodrigo Mercado Peluffo, a.
# 		 wp false: 168 chunk: su natal tierra
# 		 wp false: 169 chunk: la «oportunidad
# 		 wp false: 170 chunk: »
# 		 wp false: 171 chunk: Rodrigo Mercado Peluffo
# 		 wp false: 172 chunk: a.
# 	 with process: En su natal tierra tuvo la oportunidad de conocer a Rodrigo Mercado Peluffo a
# 		 wp true: 173 chunk: su natal tierra
# 		 wp true: 174 chunk: la oportunidad
# 		 wp true: 175 chunk: Rodrigo Mercado Peluffo
# 		 wp nc true: [{'nc': su natal tierra, 'np': [su natal tierra, En su natal tierra]}, {'nc': la oportunidad, 'np': [la oportunidad, la oportunidad de conocer a Rodrigo Mercado Peluffo]}, {'nc': Rodrigo Mercado Peluffo, 'np': [Rodrigo Mercado Peluffo, a Rodrigo Mercado Peluffo]}]
# 		 ent nc true: Rodrigo Mercado Peluffo PER
# 		 wp nc true verb_phrases 2: tuvo
# 		 wp nc true verb_phrases 2: conocer
# sent #  10 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: «Cadena» y a Uber Banquez Martínez, a.
# 		 wp false: 176 chunk: «Cadena»
# 		 wp false: 177 chunk: Uber Banquez Martínez
# 		 wp false: 178 chunk: a.
# 	 with process: Cadena y a Uber Banquez Martínez a
# 		 wp true: 179 chunk: Cadena
# 		 wp true: 180 chunk: Uber Banquez Martínez
# 		 wp nc true: [{'nc': Cadena, 'np': [Cadena, Cadena y a Uber Banquez Martínez a]}, {'nc': Uber Banquez Martínez, 'np': [Uber Banquez Martínez, y a Uber Banquez Martínez]}]
# 		 ent nc true: Uber Banquez Martínez PER
# sent #  11 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: «Juancho Dique», comandantes del Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia, quienes le propusieron vincularse a ese estructura ilegal, por dicha razón, ingresó en marzo o abril del año 2002, por intermedio de Pedro Vásquez, conocido con el a.
# 		 wp false: 181 chunk: «Juancho Dique»
# 		 wp false: 182 chunk: comandantes
# 		 wp false: 183 chunk: Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia
# 		 wp false: 184 chunk: quienes
# 		 wp false: 185 chunk: le
# 		 wp false: 186 chunk: ese estructura
# 		 wp false: 187 chunk: razón
# 		 wp false: 188 chunk: marzo
# 		 wp false: 189 chunk: abril
# 		 wp false: 190 chunk: intermedio
# 		 wp false: 191 chunk: Pedro Vásquez
# 		 wp false: 192 chunk: el a.
# 	 with process: Juancho Dique comandantes del Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia quienes le propusieron vincularse a ese estructura ilegal por dicha razón ingresó en marzo o abril del año 2002 por intermedio de Pedro Vásquez conocido con el a
# 		 wp true: 193 chunk: Juancho Dique
# 		 wp true: 194 chunk: comandantes
# 		 wp true: 195 chunk: Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia
# 		 wp true: 196 chunk: quienes
# 		 wp true: 197 chunk: le
# 		 wp true: 198 chunk: ese estructura
# 		 wp true: 199 chunk: razón
# 		 wp true: 200 chunk: marzo
# 		 wp true: 201 chunk: abril
# 		 wp true: 202 chunk: intermedio
# 		 wp true: 203 chunk: Pedro Vásquez
# 		 wp nc true: [{'nc': Juancho Dique, 'np': [Juancho Dique, Juancho Dique comandantes del Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia quienes le propusieron vincularse a ese estructura ilegal por dicha razón]}, {'nc': comandantes, 'np': [comandantes, comandantes]}, {'nc': Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia, 'np': [Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia, del Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia]}, {'nc': quienes, 'np': [quienes, quienes]}, {'nc': le, 'np': [le, le]}, {'nc': ese estructura, 'np': [ese estructura, a ese estructura ilegal]}, {'nc': razón, 'np': [razón, por dicha razón]}, {'nc': marzo, 'np': [marzo, en marzo o abril del año 2002]}, {'nc': abril, 'np': [abril, o abril]}, {'nc': intermedio, 'np': [intermedio, intermedio]}, {'nc': Pedro Vásquez, 'np': [Pedro Vásquez, por intermedio de Pedro Vásquez conocido con el a]}]
# 		 ent nc true: Juancho Dique PER
# 		 ent nc true: Bloque Héroes de los Montes de María de las Autodefensas Unidas de Colombia LOC
# 		 ent nc true: Pedro Vásquez PER
# 		 wp nc true verb_phrases 2: propusieron
# 		 wp nc true verb_phrases 2: propusieron vincularse
# 		 wp nc true verb_phrases 2: vincularse
# 		 wp nc true verb_phrases 2: ingresó
# sent #  12 ------------------------------------------------------------------------------------------------------------------------------------------------------
# 	 without process: «Pedrito», quien también residía en esa región.
# 		 wp false: 204 chunk: «Pedrito»
# 		 wp false: 205 chunk: quien
# 		 wp false: 206 chunk: esa región
# 	 with process: Pedrito quien también residía en esa región
# 		 wp true: 207 chunk: Pedrito
# 		 wp true: 208 chunk: quien
# 		 wp true: 209 chunk: esa región
# 		 wp nc true: [{'nc': Pedrito, 'np': [Pedrito, Pedrito quien también residía en esa región]}, {'nc': quien, 'np': [quien, quien]}, {'nc': esa región, 'np': [esa región, en esa región]}]
# 		 ent nc true: Pedrito PER

# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
for i in tqdm(range(0, len(list_texts_corpus)), desc ="Structure Corpus"):  
    single_doc = list_texts_corpus[i]   
    count_page = 0
    count_sent = 0
    count_sent_local = 0
    for page_raw in single_doc['pages_raw']:
        count_page += 1
        count_sent_local = 0
        text_raw = page_raw
        text_raw = re.sub('\n+',' ', text_raw)
        text_raw = re.sub('\s+',' ', text_raw)
        sents_raw = nltk.sent_tokenize(text_raw)
        for item in sents_raw:
            dict_sent = {'page': count_page, 'local_sent': count_sent_local, 'global_sent': count_sent, 'text_raw': item, 'text_clear': '', 'chunks': [], 'verbs': [], 'entities': [] }
            count_sent += 1
            count_sent_local += 1
            item = re.sub(r"[^- \w]|_", "", item)
            dict_sent['text_clear'] = item            
#             if count_sent % 100 == 0:
#                 print('sent # ', count_sent, '-'*150)
#                 print('\t with process:', item)
            doc = nlp(item)
            np_state = True
            count_chunk = 0
            for np in doc.noun_chunks:
                np_state = False
                count_chunk += 1 
                dict_sent['chunks'].append({'num': count_chunk, 'text': np.text})
            for entity in doc.ents:
                dict_sent['entities'].append({'type': entity.label_, 'text': entity.text})                
            nlp_verb_phrases = textacy.make_spacy_doc(item, lang=name_global_model_spacy)
            verb_phrases = textacy.extract.matches(nlp_verb_phrases, verb_pattern)
            count_chunk = 0
            for vp in verb_phrases:
                count_chunk += 1 
                dict_sent['verbs'].append({'num': count_chunk, 'text': vp.text})                
#                 if count_sent % 100 == 0:
#                     print('\t\t wp true:', count, 'chunk:', np.text)
#             if np_state:
#                 if count_sent % 100 == 0:
#                     print('\t\t error: This sentence has no noun phrase.')                    
            list_texts_corpus[i]['sentences'].append(dict_sent)
# Out:
# Structure Corpus: 100%|██████████| 9/9 [26:45<00:00, 178.41s/it]

# %%
{'path': single_file, 'file_name': file_name, 'date': date_time_obj, 'year': date_time_obj.year, 'month': date_time_obj.month, 'day': date_time_obj.day, 'num_pages': len(pdf), 'pages_raw': list(pdf),  
                  'text_raw': "\n\n".join(pdf), 'sentences': [], 'doc_parser': []}
{'page': count_page, 'local_sent': count_sent_local, 'global_sent': count_sent, 'text_raw': item, 'text_clear': '', 'chunks': [], 'verbs': [], 'entities': [] }

# %%
# 1550 - 2100
print(len(list_texts_corpus[2]['sentences']),list_texts_corpus[2]['num_pages'], list_texts_corpus[2]['sentences'][2100])
# Out:
# 2839 291 {'page': 198, 'local_sent': 7, 'global_sent': 2100, 'text_raw': 'El 25 de mayo de 2004, la Fiscalía Quinta Delegada ante los Juzgados Penales del Circuito de Bucaramanga, precluyó la investigación a favor de Robinson Santiago Castilla por el delito de receptación y falsedad marcaria.', 'text_clear': 'El 25 de mayo de 2004 la Fiscalía Quinta Delegada ante los Juzgados Penales del Circuito de Bucaramanga precluyó la investigación a favor de Robinson Santiago Castilla por el delito de receptación y falsedad marcaria', 'chunks': [{'num': 1, 'text': 'la Fiscalía Quinta Delegada'}, {'num': 2, 'text': 'los Juzgados Penales del Circuito de Bucaramanga'}, {'num': 3, 'text': 'la investigación'}, {'num': 4, 'text': 'Robinson Santiago Castilla'}, {'num': 5, 'text': 'el delito'}, {'num': 6, 'text': 'receptación'}, {'num': 7, 'text': 'falsedad'}], 'verbs': [{'num': 1, 'text': 'precluyó'}], 'entities': [{'type': 'ORG', 'text': 'Fiscalía Quinta Delegada'}, {'type': 'ORG', 'text': 'Juzgados Penales del Circuito de Bucaramanga'}, {'type': 'PER', 'text': 'Robinson Santiago Castilla'}]}

# %%
# noun_pharses=set()    
# for nc in doc.noun_chunks:
#     for np in [nc, doc[nc.root.left_edge.i:nc.root.right_edge.i+1]]:
#        noun_pharses.add(np)

# %%
# doc = {'path': single_file, 'file_name': file_name, 'date': date_time_obj, 'year': date_time_obj.year, 'month': date_time_obj.month, 'day': date_time_obj.day, 'num_pages': len(pdf), 'pages_raw': list(pdf),  
#                   'text_raw': "\n\n".join(pdf), 'sentences': [], 'doc_parser': []}
# dict_sent = {'page': count_page, 'local_sent': count_sent_local, 'global_sent': count_sent, 'text_raw': item, 'text_clear': '', 'chunks': [], 'verbs': []}
label_sent = []
label_chunk_sent = {}
label_chunk = []
label_ent_sent = {}
label_ent = []
label_verb_sent = {}
label_verb = []
for item in list_texts_corpus[2:3]:
    label_sent.append(item['file_name'])
    key_name = item['file_name'] #item['file_name'].lower().strip()
    print(key_name)
    label_chunk_sent[key_name] = [item_chunk['text'].lower() for sent in item['sentences'][1550:2100] for item_chunk in sent['chunks']  if len(item_chunk['text'].split(' ')) > 1]
    label_chunk += label_chunk_sent[key_name]
    label_ent_sent[key_name] = [item_ent['text'].lower() for sent in item['sentences'][1550:2100] for item_ent in sent['entities'] ] #if item_ent['type'] == 'PER'
    label_ent += label_ent_sent[key_name]
    label_verb_sent[key_name] = [item_verb['text'].lower() for sent in item['sentences'][1550:2100] for item_verb in sent['entities'] ] #if item_ent['type'] == 'PER'
    label_verb += label_verb_sent[key_name]
print(label_sent) 
print('label_chunk', len(label_chunk), len(set(label_chunk)))
print('label_ent', len(label_ent), len(set(label_ent_sent)))
# print(label_chunk)

from collections import Counter
word_freq = Counter(label_chunk)
common_words = word_freq.most_common(100)
print(common_words)

cfd = nltk.ConditionalFreqDist(
           (title, word)
           for title in label_sent
           for word in label_chunk_sent[title])

label_words = [word for (word, freq) in common_words]
print(label_words)
# cfd.tabulate(conditions=label_sent, samples=label_words)
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 8)) 
cfd.plot(conditions=label_sent, samples=label_words)
plt.figure(figsize=(20, 8))
cfd.plot(conditions=label_sent, samples=label_words, cumulative=True)
# Out:
# Armando Madriaga Picón y Jesús Noraldo Basto
# ['Armando Madriaga Picón y Jesús Noraldo Basto']
# label_chunk 2269 923
# label_ent 1232 1
# [('los numerales', 64), ('las circunstancias', 63), ('tribunal superior de bogotá sala de justicia y paz radicado', 57), ('código penal', 55), ('jesús noraldo basto león', 48), ('los hechos', 45), ('el artículo', 42), ('los artículos', 40), ('el hecho', 39), ('los argumentos', 38), ('la pena', 35), ('el momento', 35), ('la ley 599 de 2000', 34), ('el decreto 100 de 1980', 31), ('la víctima', 24), ('los punibles', 23), ('la guerrilla', 22), ('mario castro', 22), ('las hostilidades', 21), ('la cc', 20), ('la muerte', 20), ('sala de justicia', 19), ('tribunal superior de bogotá', 19), ('aguachica cesar', 18), ('el mismo hecho', 18), ('la misma calificación', 18), ('armando madriaga picón alias maría bonita', 17), ('la fiscalía', 14), ('la ley', 13), ('el señor', 13), ('la situación', 12), ('la comisión', 11), ('la paz', 11), ('lester maría gonzalézromero', 11), ('el delito', 10), ('las fuerzas', 9), ('la fiscalía 34 de la unidad nacional para la justicia', 9), ('los términos', 9), ('la acción', 9), ('jesus noraldo basto leon', 8), ('el comandante', 8), ('un grupo', 8), ('las personas', 8), ('julio peinado becerra', 7), ('la sala', 7), ('la organización', 6), ('el municipio', 6), ('los delitos', 6), ('las víctimas', 6), ('concurso heterogéneo', 6), ('el desplazamiento', 6), ('la calle', 6), ('los miembros', 6), ('la prescripción', 6), ('los grupos', 6), ('la protección', 6), ('la legalidad', 5), ('la libertad', 5), ('el uso', 5), ('maría bonita', 5), ('el grupo', 5), ('el postulado', 5), ('el cargo', 5), ('el concepto', 5), ('un taxi', 5), ('la señora', 5), ('el campo', 5), ('la carrera', 5), ('el establecimiento', 5), ('los crimenes', 5), ('la participación', 5), ('los anteriores argumentos', 4), ('la fuerza', 4), ('el fundamento', 4), ('la conducta', 4), ('su participación', 4), ('las autodefensas', 4), ('el derecho', 4), ('los señores', 4), ('el chavo', 4), ('la ciudad', 4), ('el caso', 4), ('los conflictos', 4), ('las partes', 4), ('la gpdh', 4), ('jesus noraldo', 3), ('el marco', 3), ('una persona', 3), ('una parte', 3), ('la población', 3), ('san martín', 3), ('el frente héctor', 3), ('la vida', 3), ('frente héctor julio peinado becerra', 3), ('las armas', 3), ('su vinculación', 3), ('frente héctor', 3), ('la comunidad', 3), ('la localidad', 3), ('los elementos', 3)]
# ['los numerales', 'las circunstancias', 'tribunal superior de bogotá sala de justicia y paz radicado', 'código penal', 'jesús noraldo basto león', 'los hechos', 'el artículo', 'los artículos', 'el hecho', 'los argumentos', 'la pena', 'el momento', 'la ley 599 de 2000', 'el decreto 100 de 1980', 'la víctima', 'los punibles', 'la guerrilla', 'mario castro', 'las hostilidades', 'la cc', 'la muerte', 'sala de justicia', 'tribunal superior de bogotá', 'aguachica cesar', 'el mismo hecho', 'la misma calificación', 'armando madriaga picón alias maría bonita', 'la fiscalía', 'la ley', 'el señor', 'la situación', 'la comisión', 'la paz', 'lester maría gonzalézromero', 'el delito', 'las fuerzas', 'la fiscalía 34 de la unidad nacional para la justicia', 'los términos', 'la acción', 'jesus noraldo basto leon', 'el comandante', 'un grupo', 'las personas', 'julio peinado becerra', 'la sala', 'la organización', 'el municipio', 'los delitos', 'las víctimas', 'concurso heterogéneo', 'el desplazamiento', 'la calle', 'los miembros', 'la prescripción', 'los grupos', 'la protección', 'la legalidad', 'la libertad', 'el uso', 'maría bonita', 'el grupo', 'el postulado', 'el cargo', 'el concepto', 'un taxi', 'la señora', 'el campo', 'la carrera', 'el establecimiento', 'los crimenes', 'la participación', 'los anteriores argumentos', 'la fuerza', 'el fundamento', 'la conducta', 'su participación', 'las autodefensas', 'el derecho', 'los señores', 'el chavo', 'la ciudad', 'el caso', 'los conflictos', 'las partes', 'la gpdh', 'jesus noraldo', 'el marco', 'una persona', 'una parte', 'la población', 'san martín', 'el frente héctor', 'la vida', 'frente héctor julio peinado becerra', 'las armas', 'su vinculación', 'frente héctor', 'la comunidad', 'la localidad', 'los elementos']

# %%
from collections import Counter
word_freq = Counter(label_ent)
common_words = word_freq.most_common(100)
print(common_words)

cfd = nltk.ConditionalFreqDist(
           (title, word)
           for title in label_sent
           for word in label_ent_sent[title])

label_words = [word for (word, freq) in common_words]
print(label_words)

# cfd.tabulate(conditions=label_sent, samples=label_words)
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 8)) 
cfd.plot(conditions=label_sent, samples=label_words)
plt.figure(figsize=(20, 8))
cfd.plot(conditions=label_sent, samples=label_words, cumulative=True)
# Out:
# [('tribunal superior de bogotá sala de justicia', 57), ('postulados armando madriaga picón', 57), ('jesús noraldo basto león', 54), ('código penal', 54), ('decreto 100', 44), ('la ley', 40), ('maría bonita', 34), ('audiencia', 33), ('armando madriaga picón', 32), ('aguachica', 25), ('mario castro', 22), ('aguachica cesar', 19), ('tribunal superior de bogotá', 19), ('dra', 18), ('lester maría gonzalézromero', 18), ('juan francisco prada', 16), ('homicidio', 14), ('sala de justicia y paz', 13), ('fiscalía', 12), ('leon', 11), ('jesus', 11), ('frente héctor julio peinado becerra', 11), ('rancho', 8), ('rubiano', 8), ('picon', 7), ('chorola', 7), ('fiscalía 34 de la unidad nacional para la justicia y la paz', 6), ('identificado', 6), ('caliche', 5), ('armando', 4), ('unidad nacional para la justicia y la paz', 4), ('el chavo', 4), ('chavo', 4), ('derecho internacional humanitario', 4), ('la sala', 4), ('jesus noraldo', 3), ('utilización', 3), ('basto leon', 3), ('alfredo ballena', 3), ('san martín', 3), ('sur', 3), ('fiscalía 34 de la', 3), ('pardillo', 3), ('ídem', 3), ('ocaña', 3), ('juancho prada', 3), ('yesid delgado', 3), ('william bautista', 3), ('carlos andrés carreño', 3), ('carlos', 3), ('comité internacional de la cruz roja', 3), ('noción de participación directa', 3), ('hostilidades', 3), ('art', 3), ('schmitt michael', 3), ('artículo 3 común', 3), ('armando madriaga picon', 2), ('corte suprema de justicia sala de casación penal', 2), ('especial', 2), ('bloque central bolívar', 2), ('josé nahin franco', 2), ('identificada', 2), ('gamarra', 2), ('henry flórez hernández', 2), ('el 5', 2), ('javier quintero', 2), ('aguas claras', 2), ('jairo martínez rincón', 2), ('víctor manuel flórez', 2), ('josé del carmen castro', 2), ('cúcuta', 2), ('josé mario saldaña flórez', 2), ('gloria', 2), ('william saldaña flórez', 2), ('convención', 2), ('robinson santiago castilla', 2), ('según', 2), ('luís ofrego ovalle gaona', 2), ('sur del cesar', 2), ('juan francisco prada márquez', 2), ('juzgado tercero penal', 2), ('circuito especializado de bucaramanga', 2), ('según la guía interpretativa', 2), ('parte', 2), ('dih', 2), ('challenges of twenty-first century conflicts a look at direct participation in hostilities duke journal of comparative and international law volume 20', 2), ('gpdh', 2), ('corte penal', 2), ('el artículo 346 del código penal', 1), ('estado incurrirá', 1), ('la mencionada norma emplea once', 1), ('armando madriaga', 1), ('el artículo 197 de la ley 599 de 2000', 1), ('secuestro', 1), ('el artículo 168 de la ley 599 de 2000', 1), ('el que con propósitos distintos a los previstos en el artículo siguiente arrebate', 1), ('se concreta este delito', 1), ('corte suprema de justicia', 1), ('corporación', 1), ('el artículo 287 de la ley 599 de 2000', 1)]
# ['tribunal superior de bogotá sala de justicia', 'postulados armando madriaga picón', 'jesús noraldo basto león', 'código penal', 'decreto 100', 'la ley', 'maría bonita', 'audiencia', 'armando madriaga picón', 'aguachica', 'mario castro', 'aguachica cesar', 'tribunal superior de bogotá', 'dra', 'lester maría gonzalézromero', 'juan francisco prada', 'homicidio', 'sala de justicia y paz', 'fiscalía', 'leon', 'jesus', 'frente héctor julio peinado becerra', 'rancho', 'rubiano', 'picon', 'chorola', 'fiscalía 34 de la unidad nacional para la justicia y la paz', 'identificado', 'caliche', 'armando', 'unidad nacional para la justicia y la paz', 'el chavo', 'chavo', 'derecho internacional humanitario', 'la sala', 'jesus noraldo', 'utilización', 'basto leon', 'alfredo ballena', 'san martín', 'sur', 'fiscalía 34 de la', 'pardillo', 'ídem', 'ocaña', 'juancho prada', 'yesid delgado', 'william bautista', 'carlos andrés carreño', 'carlos', 'comité internacional de la cruz roja', 'noción de participación directa', 'hostilidades', 'art', 'schmitt michael', 'artículo 3 común', 'armando madriaga picon', 'corte suprema de justicia sala de casación penal', 'especial', 'bloque central bolívar', 'josé nahin franco', 'identificada', 'gamarra', 'henry flórez hernández', 'el 5', 'javier quintero', 'aguas claras', 'jairo martínez rincón', 'víctor manuel flórez', 'josé del carmen castro', 'cúcuta', 'josé mario saldaña flórez', 'gloria', 'william saldaña flórez', 'convención', 'robinson santiago castilla', 'según', 'luís ofrego ovalle gaona', 'sur del cesar', 'juan francisco prada márquez', 'juzgado tercero penal', 'circuito especializado de bucaramanga', 'según la guía interpretativa', 'parte', 'dih', 'challenges of twenty-first century conflicts a look at direct participation in hostilities duke journal of comparative and international law volume 20', 'gpdh', 'corte penal', 'el artículo 346 del código penal', 'estado incurrirá', 'la mencionada norma emplea once', 'armando madriaga', 'el artículo 197 de la ley 599 de 2000', 'secuestro', 'el artículo 168 de la ley 599 de 2000', 'el que con propósitos distintos a los previstos en el artículo siguiente arrebate', 'se concreta este delito', 'corte suprema de justicia', 'corporación', 'el artículo 287 de la ley 599 de 2000']

# %%
from collections import Counter
word_freq = Counter(label_verb)
common_words = word_freq.most_common(100)
print(common_words)

cfd = nltk.ConditionalFreqDist(
           (title, word)
           for title in label_sent
           for word in label_verb_sent[title])

label_words = [word for (word, freq) in common_words]
print(label_words)

# cfd.tabulate(conditions=label_sent, samples=label_words)
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 8)) 
cfd.plot(conditions=label_sent, samples=label_words)
plt.figure(figsize=(20, 8))
cfd.plot(conditions=label_sent, samples=label_words, cumulative=True)
# Out:
# []
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-8086c4797de5> in <module>
#       4 print(common_words)
#       5
# ----> 6 cfd = nltk.ConditionalFreqDist(
#       7            (title, word)
#       8            for title in label_sent
#
# ~/anaconda3/lib/python3.8/site-packages/nltk/probability.py in __init__(self, cond_samples)
#    1898
#    1899         if cond_samples:
# -> 1900             for (cond, sample) in cond_samples:
#    1901                 self[cond][sample] += 1
#    1902
#
# <ipython-input-59-8086c4797de5> in <genexpr>(.0)
#       7            (title, word)
#       8            for title in label_sent
# ----> 9            for word in label_verb_sent[title])
#      10
#      11 label_words = [word for (word, freq) in common_words]
#
# KeyError: 'Armando Madriaga Picón y Jesús Noraldo Basto'

# %%
# label_sent = []
# label_chunk_sent = {}
# label_chunk = []
import numpy as np
import pandas as pd

my_array = np.array([[item, sent_name] for sent_name in label_ent_sent for item in label_ent_sent[sent_name]] , dtype=object)

data = pd.DataFrame(my_array, columns = ['label', 'sent'])

print(data)
print(type(data))
print(data.dtypes)
# Out:
#                                                 label  \
# 0        tribunal superior de bogotá sala de justicia
# 1                   postulados armando madriaga picón
# 2                            jesús noraldo basto león
# 3                                            fiscalía
# 4                              armando madriaga picon
# ...                                               ...
# 1227                       robinson santiago castilla
# 1228                                               no
# 1229                                      sijin desan
# 1230                                           no 865
# 1231  estación de polícia de la localidad de engativa
#
#                                               sent
# 0     Armando Madriaga Picón y Jesús Noraldo Basto
# 1     Armando Madriaga Picón y Jesús Noraldo Basto
# 2     Armando Madriaga Picón y Jesús Noraldo Basto
# 3     Armando Madriaga Picón y Jesús Noraldo Basto
# 4     Armando Madriaga Picón y Jesús Noraldo Basto
# ...                                            ...
# 1227  Armando Madriaga Picón y Jesús Noraldo Basto
# 1228  Armando Madriaga Picón y Jesús Noraldo Basto
# 1229  Armando Madriaga Picón y Jesús Noraldo Basto
# 1230  Armando Madriaga Picón y Jesús Noraldo Basto
# 1231  Armando Madriaga Picón y Jesús Noraldo Basto
#
# [1232 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# label    object
# sent     object
# dtype: object

# %%
print(data.nunique())
print(data['label'].value_counts().sort_index())
values = data[['label', 'sent']]
# Out:
# label    508
# sent       1
# dtype: int64
# 1 n a no 29h-26 del municipio de aguachica cesar    1
# 12 de agosto 1949                                   1
# 306 sala de justicia y paz                          1
# 332 sala de justicia y paz                          1
# 339 sala de justicia y paz                          1
#                                                    ..
# wilson solis sierra                                 1
# yamaha de placa gkq-77                              1
# yesid delgado                                       3
# él                                                  1
# ídem                                                3
# Name: label, Length: 508, dtype: int64

# %%
sorted_values = values['label'].sort_values().unique()

from dirty_cat import SimilarityEncoder

similarity_encoder = SimilarityEncoder(similarity='ngram')
transformed_values = similarity_encoder.fit_transform(
    sorted_values.reshape(-1, 1))

# %%
from sklearn.manifold import MDS

mds = MDS(dissimilarity='precomputed', n_init=10, random_state=42)
two_dim_data = mds.fit_transform(
    1 - transformed_values)  # transformed values lie
# in the 0-1 range, so 1-transformed_value yields a positive dissimilarity matrix
print(two_dim_data.shape)
print(sorted_values.shape)
# Out:
# (508, 2)
# (508,)

# %%
import numpy as np

n_points = 50
np.random.seed(42)
from sklearn.neighbors import NearestNeighbors

random_points = np.random.choice(len(similarity_encoder.categories_[0]),n_points, replace=False)
nn = NearestNeighbors(n_neighbors=2).fit(transformed_values)
_, indices_ = nn.kneighbors(transformed_values[random_points])
indices = np.unique(indices_.squeeze())

# %%
import matplotlib.pyplot as plt
# plt.figure(figsize=(20, 8)) 
f, ax = plt.subplots(figsize=(20, 8))
ax.scatter(x=two_dim_data[indices, 0], y=two_dim_data[indices, 1])
# adding the legend
for x in indices:
    ax.text(x=two_dim_data[x, 0], y=two_dim_data[x, 1], s=sorted_values[x],
            fontsize=8)
ax.set_title('multi-dimensional-scaling representation using a 3gram similarity matrix')
# Out:
# Text(0.5, 1.0, 'multi-dimensional-scaling representation using a 3gram similarity matrix')

# %%
f2, ax2 = plt.subplots(figsize=(20, 20))
cax2 = ax2.matshow(transformed_values[indices, :][:, indices])
ax2.set_yticks(np.arange(len(indices)))
ax2.set_xticks(np.arange(len(indices)))
ax2.set_yticklabels(sorted_values[indices], rotation='30')
ax2.set_xticklabels(sorted_values[indices], rotation='60', ha='right')
ax2.xaxis.tick_bottom()
ax2.set_title('Similarities across categories')
f2.colorbar(cax2)
f2.tight_layout()
